# %%
import re

##Importing the scripts and stripping them of numbers and special signs

M1= open("/Users/lydiastenflo/Dropbox/My Mac (Magnuss MacBook Air (2))/Desktop/HP1.csv").read()
M1= re.sub(r"[^a-zA-Z]"," ", M1)

M2= open("/Users/lydiastenflo/Dropbox/My Mac (Magnuss MacBook Air (2))/Desktop/HP2.csv").read()
M2= re.sub(r"[^a-zA-Z]"," ", M2)

M3= open("/Users/lydiastenflo/Dropbox/My Mac (Magnuss MacBook Air (2))/Desktop/HP3.csv").read()
M3= re.sub(r"[^a-zA-Z]"," ", M3)

M4= open("/Users/lydiastenflo/Dropbox/My Mac (Magnuss MacBook Air (2))/Desktop/HP4.csv").read()
M4= re.sub(r"[^a-zA-Z]"," ", M4)

M5= open("/Users/lydiastenflo/Dropbox/My Mac (Magnuss MacBook Air (2))/Desktop/HP5.csv").read()
M5= re.sub(r"[^a-zA-Z]"," ", M5)

M6= open("/Users/lydiastenflo/Dropbox/My Mac (Magnuss MacBook Air (2))/Desktop/HP6.csv").read()
M6= re.sub(r"[^a-zA-Z]"," ", M6)

M7= open("/Users/lydiastenflo/Dropbox/My Mac (Magnuss MacBook Air (2))/Desktop/HP7.csv").read()
M7= re.sub(r"[^a-zA-Z]"," ", M7)

M8= open("/Users/lydiastenflo/Dropbox/My Mac (Magnuss MacBook Air (2))/Desktop/HP8.csv").read()
M8= re.sub(r"[^a-zA-Z]"," ", M8)

listofmovies=[M1, M2, M3, M4, M5, M6, M7, M8]

# %%
##Counting the words in each script

countsofwords=[len(M1.split()), len(M2.split()), len(M3.split()), len(M4.split()), len(M5.split()), len(M6.split()), len(M7.split()), len(M8.split())]
print(countsofwords)
# Out:
# [8891, 11804, 9846, 5869, 8973, 10021, 8777, 5683]

# %%
##Creating the character class

class Character:  
    def __init__(self, name, listofmentions): 
        self.name=name 
        self.listofmentions=listofmentions

# %%
import csv

#Creating the list of characters

file=open("/Users/lydiastenflo/Dropbox/My Mac (Magnuss MacBook Air (2))/Desktop/character_names_updated.csv",'r').readlines()
listofcharacters=[]
for char in file:
  if 'character_primary_name' not in char:
    char=char.strip()
    char=char.replace('-', ' ')
    listofcharacters.append(char)

print(listofcharacters)


#And an empty list of character instances 
listofinstances=[]
# Out:
# ['Aberforth', 'Alastor', 'Albus', 'Alecto', 'Alice', 'Alicia', 'Amos', 'Amycus', 'Angelina', 'Anthony', 'Antonin', 'Augustus', 'Aurora', 'Bellatrix', 'Benjy', 'Bill', 'Blaise', 'Bloody', 'Cedric', 'Charity', 'Charles', 'Cho', 'Colin', 'Corban', 'Cormac', 'Crouch Jr.', 'Crouch Sr.', 'Cuthbert', 'Dean', 'Dedalus', 'Dennis', 'Dobby', 'Dolores', 'Dorcas', 'Draco', 'Dudley', 'Dumbledore', 'Edgar', 'Elphias', 'Emmeline', 'Ernest', 'Fabian', 'He Who Must Not Be Named', 'Fat', 'Fenrir', 'Filch', 'Firenze', 'Fleur', 'Flint', 'Flitwick', 'Frank', 'Fred', 'Fudge', 'Gabrielle', 'Gellert', 'George', 'Gideon', 'Ginny', 'Godric', 'Graham', 'Gregory', 'Hagrid', 'Hannah', 'The Dark Lord', 'Harry', 'Helena', 'Helga', 'Hermione', 'Hestia', 'Horace', 'Igor', 'Irma', 'James', 'James Sirius', 'Justin', 'Katie', 'Kingsley', 'Kreacher', 'Lavender', 'Lee', 'Lily', 'Lockhart', 'Lucius', 'Luna', 'Lupin', 'Madam Hooch', 'Madame', 'Marcus', 'Marge', 'Marietta', 'Marlene', 'McGonagall', 'Michael', 'Millicent', 'M
# ...

# %%
import pandas as pd

#Generate a dictionary for every name in the list of characters:
def generate_dicts(listofcharacters):
    for name in listofcharacters:
        count(name, listofmovies)



#Counting the mentions:
def count(name, listofmovies):
    listofmentions={} #creating an empty dictionary for the character

    char_instance=Character(name, listofmentions) #creating an instance
    listofinstances.append(char_instance)

    n=0

    for movie in listofmovies: #for every movie
        n+=1
        i=0
        filmname=f"Film {n}:"   
        #temp= re.escape(name)
        #temp1=(r"\b" + temp + r"\b")
        i=len([*re.finditer(name, movie)]) #counting the occurences of the pattern in the movie
        char_instance.listofmentions[filmname]=i 
    
    return char_instance.listofmentions


#Make the dataframe:

def makedf(listofinstances):
    df = pd.DataFrame(None) 
    for instance in listofinstances:
        index=[instance.name]
        df_temp = pd.DataFrame({'counts': [instance.listofmentions]}, columns = ['counts'])
        df_temp=df_temp.rename_axis('Character_Primary_Name')
        df_temp=df_temp['counts'].apply(pd.Series)
        df_temp.index=index

        df=pd.concat([df, df_temp], axis=0)


    return df


generate_dicts(listofcharacters)
df=makedf(listofinstances)
df=df.rename_axis('Character_Primary_Name')


#Export the dataframe to a CSV
df.to_csv('final_csv_movies.csv')

df.head()
# Out:
#                         Film 1:  Film 2:  Film 3:  Film 4:  Film 5:  Film 6:  \
# Character_Primary_Name
# Aberforth                     0        0        0        0        0        0
# Alastor                       0        0        0        6        0        0
# Albus                         3        3        0        2        2        3
# Alecto                        0        0        0        0        0        0
# Alice                         0        0        0        0        1        0
#
#                         Film 7:  Film 8:
# Character_Primary_Name
# Aberforth                     2        2
# Alastor                       0        0
# Albus                         2        3
# Alecto                        0        0
# Alice                         0        0
